# %%
import numpy as np
from scipy.interpolate import make_interp_spline
import matplotlib.pyplot as plt
 



y = np.array([0,31562,40960,27205,32442,23713,35611,34859,38756,0])

x= [' Mar 24 23:30','Mar 25 11:30','Mar 25 23:30','Mar 26 11:30','Mar 26 23:30','Mar 27 12:30','Mar 28 00:30','Mar 28 12:30','Mar 29 00:30','Mar 29 12:30']

xf=np.arange((len(x)))
X_Y_Spline = make_interp_spline(xf, y)
 
# Returns evenly spaced numbers
# over a specified interval.
X_ = np.linspace(xf.min(), xf.max(), 500)
Y_ = X_Y_Spline(X_)
 
# plotting the points
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.size': 9})
plt.plot(X_,Y_, color= "red",linestyle="solid")
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}'))
plt.xticks(xf,x,rotation=90)

plt.xlabel('Time (GMT)')
# naming the y axis
plt.ylabel('Number of tweets')

#plt.title('Distribution of Tweets over Retreival')

plt.grid()
#plt.figure(figsize=(20,10))
plt.savefig('timegraph.png',format='png',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()

# %%
import numpy as np
from scipy.interpolate import make_interp_spline
import matplotlib.pyplot as plt
 



y = np.array([0,31562,40960,27205,32442,23713,35611,34859,38756,0])

x= [' Mar 24 23:30','Mar 25 11:30','Mar 25 23:30','Mar 26 11:30','Mar 26 23:30','Mar 27 11:30','Mar 27 23:30','Mar 28 11:30','Mar 28 23:30','Mar 29 11:30']

xf=np.arange((len(x)))
X_Y_Spline = make_interp_spline(xf, y)
 
# Returns evenly spaced numbers
# over a specified interval.
X_ = np.linspace(xf.min(), xf.max(), 500)
Y_ = X_Y_Spline(X_)
 
# plotting the points
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.weight':'normal'})
plt.rcParams.update({'font.size': 9})
plt.plot(X_,Y_, color= "red",linestyle="solid")
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}'))
plt.xticks(xf,x,rotation=90)

plt.xlabel('Time (GMT -1)')
# naming the y axis
plt.ylabel('Number of tweets')

#plt.title('Distribution of Tweets over Retreival')

plt.grid()
#plt.figure(figsize=(20,10))
#plt.savefig('timegraph_normal.png',format='png',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()

# %%
import numpy as np
from scipy.interpolate import make_interp_spline
import matplotlib.pyplot as plt
 



y = np.array([0,31562,40960,27205,32442,23713,35611,34859,38756])

x= [' Mar 24 23:30','Mar 25 11:30','Mar 25 23:30','Mar 26 11:30','Mar 26 23:30','Mar 27 11:30','Mar 27 23:30','Mar 28 11:30','Mar 28 23:30']

xf=np.arange((len(x)))
X_Y_Spline = make_interp_spline(xf, y)
 
# Returns evenly spaced numbers
# over a specified interval.
X_ = np.linspace(xf.min(), xf.max(), 500)
Y_ = X_Y_Spline(X_)
 
# plotting the points
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.size': 9})
plt.plot(X_,Y_, color= "red",linestyle="solid")
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}'))
plt.xticks(xf,x,rotation=90)

plt.xlabel('Time (GMT)')
# naming the y axis
plt.ylabel('Number of tweets')

#plt.title('Distribution of Tweets over Retreival')

plt.grid()
#plt.figure(figsize=(20,10))
plt.savefig('timegraph2.eps',format='eps',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()

# %%
pip install plotly==5.10.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.offline as pyo

# %%
import plotly.graph_objects as go

# %%
import plotly.express as px

# %%
x=[1,2,3,4]
y=[1,4,9,16]
fig=px.line(x=x,y=y,line_color='#00ff00')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ROHANA~1\AppData\Local\Temp/ipykernel_2728/2863333724.py in <module>
#       1 x=[1,2,3,4]
#       2 y=[1,4,9,16]
# ----> 3 fig=px.line(x=x,y=y,line_color='#00ff00')
#       4 fig.show()
#
# TypeError: line() got an unexpected keyword argument 'line_color'

# %%
y =[0,31562,40960,27205,32442,23713,35611,34859,38756,0]
x= [' Mar 24 23:30','Mar 25 11:30','Mar 25 23:30','Mar 26 11:30','Mar 26 23:30','Mar 27 11:30','Mar 27 23:30','Mar 28 11:30','Mar 28 23:30','Mar 29 11:30']
fig=px.line(x=x,y=y)
fig.show()
# Out:
# <div>                            <div id="8580944b-cc80-45c8-a3ee-3f19c7093ae4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8580944b-cc80-45c8-a3ee-3f19c7093ae4")) {                    Plotly.newPlot(                        "8580944b-cc80-45c8-a3ee-3f19c7093ae4",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[" Mar 24 23:30","Mar 25 11:30","Mar 25 23:30","Mar 26 11:30","Mar 26 23:30","Mar 27 11:30","Mar 27 23:30","Mar 28 11:30","Mar 28 23:30","Mar 29 11:30"],"xaxis":"x","y":[0,31562,40960,27205,32442,23713,35611,34859,38756,0],"yaxis":"y","type":"scatter"}],        
# ...

# %%
y =[0,31562,40960,27205,32442,23713,35611,34859,38756,0]
x= [' Mar 24 23:30','Mar 25 11:30','Mar 25 23:30','Mar 26 11:30','Mar 26 23:30','Mar 27 11:30','Mar 27 23:30','Mar 28 11:30','Mar 28 23:30','Mar 29 11:30']
fig=go.Figure(data=go.Scatter(x=x,y=y,line_color='rgb(255,0,0)'))
fig.show()
# Out:
# <div>                            <div id="87d62a63-4c84-44f5-8f22-7ccdd9d5b822" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87d62a63-4c84-44f5-8f22-7ccdd9d5b822")) {                    Plotly.newPlot(                        "87d62a63-4c84-44f5-8f22-7ccdd9d5b822",                        [{"line":{"color":"rgb(255,0,0)"},"x":[" Mar 24 23:30","Mar 25 11:30","Mar 25 23:30","Mar 26 11:30","Mar 26 23:30","Mar 27 11:30","Mar 27 23:30","Mar 28 11:30","Mar 28 23:30","Mar 29 11:30"],"y":[0,31562,40960,27205,32442,23713,35611,34859,38756,0],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0
# ...

# %%
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

y =np.array([0,31562,40960,27205,32442,23713,35611,34859,38756,0])
x= [' Mar 24 23:30','Mar 25 11:30','Mar 25 23:30','Mar 26 11:30','Mar 26 23:30','Mar 27 11:30','Mar 27 23:30','Mar 28 11:30','Mar 28 23:30','Mar 29 11:30']
#xf=np.arange((len(x)))

fig = go.Figure(layout_xaxis_range=[-0.1,9.1],layout_yaxis_range=[-1000,43000])
''''''
fig.add_trace(go.Scatter(x=x, y=y, name="spline",
                    text=["tweak line smoothness<br>with 'smoothing' in line object"],
                    hoverinfo='text+name',
                    line_shape='spline',
                        line_color='rgb(255,0,0)'))
fig.update_layout(
    #title="Plot Title",
    xaxis_title="Time(GMT-1) ",
    yaxis_title="Number of tweets" ,
    plot_bgcolor='white', #rgba(0,0,0,0)
    xaxis = dict(
    showgrid = True,
    zeroline = True,
    showline = True,
    showticklabels = True,
    gridwidth = 1,
    gridcolor='black',
    tickangle=270
    ),
    yaxis = dict(
    showgrid = True,
    zeroline = True,
    showline = True,
    showticklabels = True,
    gridwidth = 1,
    gridcolor='black',
    tickformat=",d"
    ),
    font=dict(
        family="Times",
        size=14,
        color="black"
    )
)
#fig.write_image("graph.png")
#fig.write_image("graph.eps")
#fig.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='black',tickangle=270,zeroline = True,showline = True, showticklabels = True)
#fig.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='black',tickformat=",d",zeroline=True,showline = True, showticklabels = True)
# Out:
# <div>                            <div id="758dad52-219b-4dd5-9d3b-dd467d71a6f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("758dad52-219b-4dd5-9d3b-dd467d71a6f6")) {                    Plotly.newPlot(                        "758dad52-219b-4dd5-9d3b-dd467d71a6f6",                        [{"hoverinfo":"text+name","line":{"color":"rgb(255,0,0)","shape":"spline"},"name":"spline","text":["tweak line smoothness<br>with 'smoothing' in line object"],"x":[" Mar 24 23:30","Mar 25 11:30","Mar 25 23:30","Mar 26 11:30","Mar 26 23:30","Mar 27 11:30","Mar 27 23:30","Mar 28 11:30","Mar 28 23:30","Mar 29 11:30"],"y":[0,31562,40960,27205,32442,23713,35611,34859,38756,0],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":
# ...

# %%
pip install -U kaleido
# Out:
# ...
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\rohanallen18\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\rohanallen18\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "C:\Users\rohanallen18\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\rohanallen18\anaconda3\lib\http\client.py", line 462, in read
#     n = self.readinto(b)
#   File "C:\Users\rohanallen18\anaconda3\lib\http\client.py", line 506, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\rohanallen18\anaconda3\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\rohanallen18\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
# ...

# %%
pip install poppler
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000026717964D30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/poppler/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000026717964910>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/poppler/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002671796A8B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/poppler/
# ...
