# %%
#text2emo
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from matplotlib.ticker import PercentFormatter
x=['Surprise','Anger','Sadness','Fear','Happiness']
y=[41599.080,12843.410,60230.670,100922.430,27647.420]
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.size': 10})
barlist=plt.bar(x, y)
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}'))
plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
barlist[0].set_color('yellow')
barlist[1].set_color('r')
barlist[2].set_color('b')
barlist[3].set_color('orange')
barlist[4].set_color('g')
#plt.savefig('rohan_uncleaned_text2emo.eps',format='eps',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()

# %%
#poms
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
x=['Anger','Depression','Fatigue','Vigour','Tension','Confusion']
y=[35841.609978418200,152800.369189866000,16426.212635922000,12997.426368800200,23215.296963257200,23827.084713017400]
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.size': 10})
barlist=plt.bar(x, y)
barlist[0].set_color('r')
barlist[1].set_color('black')
barlist[2].set_color('b')
barlist[3].set_color('orange')
barlist[4].set_color('g')
barlist[5].set_color('pink')
plt.savefig('rohan_uncleaned_poms.eps',format='eps',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()

# %%
#sentiment polarity count
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
x=['Positive','Negative','Neutral']

y1=[73788,21317,170003]
y2=[96340,87707,81061]
X_axis = np.arange(len(x))
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.size': 10})
plt.bar(X_axis - 0.2, y1, 0.4, label = 'TextBlob',color='blue')
plt.bar(X_axis + 0.2, y2, 0.4, label = 'Vader',color='red')
plt.xticks(X_axis, x)
plt.legend()
plt.savefig('rohan_uncleaned_sentiment.eps',format='eps',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
#ekman
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from matplotlib.ticker import PercentFormatter
x=['Surprise','Anger','Sadness','Fear','Joy','Disgust']
y1=[36211.71163,22521.49536,19631.10005,141714.2847,175056.9041,14625.50418]
a= [((element/409761) * 100) for element in y1]
y2=[24753.93181479630000,16114.08813893080000,16600.10332457310000,91462.14091485260000,108810.21991829900000,7367.51595351285000]
r= [((element/265108) * 100) for element in y2]
X_axis = np.arange(len(x))
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.size': 10})
plt.bar(X_axis - 0.2, a, 0.4, label = '2020',color='red')
plt.bar(X_axis + 0.2, r, 0.4, label = '2022',color='blue')
plt.xticks(X_axis, x)
#plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}'))
plt.gca().yaxis.set_major_formatter(PercentFormatter(100,0))
plt.legend(frameon=False)
#plt.savefig('2020_2022_ekman.eps',format='eps',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()

##

# %%
#plutchik
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from matplotlib.ticker import PercentFormatter
x=['Surprise','Anger','Sadness','Fear','Joy','Disgust','Trust','Anticipation']
y1=[25228.80891,17041.5685,13346.08976,99121.48023,119827.1573,10482.16749,111196.8424,13516.88551]
a= [((element/409761) * 100) for element in y1]
y2=[17410.963485149000,11952.554467160200,11142.975382823200,66112.578062035300,76142.008956867000,5102.425144881260,68168.885491499000,9075.608945875630]
r= [((element/265108) * 100) for element in y2]
X_axis = np.arange(len(x))
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.size': 8})
plt.bar(X_axis - 0.2, a, 0.4, label = '2020',color='red')
plt.bar(X_axis + 0.2, r, 0.4, label = '2022',color='blue')
plt.xticks(X_axis, x)
#plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}'))
plt.gca().yaxis.set_major_formatter(PercentFormatter(100,0))
plt.legend(frameon=False)
plt.savefig('2020_2022_plutchik.eps',format='eps',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()

# %%
#combined male-female text2emo

x=['Surprise','Anger','Sadness','Fear','Happiness']
y1=[45.31,17.62,57.45,65.76,26.82]
male = [((element/259) * 100) for element in y1]
y2=[162,47.92,159.94,177.31,60.39]
female = [((element/709) * 100) for element in y2]
X_axis = np.arange(len(x))
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.family':'Times Roman'})
plt.rcParams.update({'font.size': 10})
plt.bar(X_axis - 0.2, male, 0.4, label = 'Male',color='blue')
plt.bar(X_axis + 0.2, female, 0.4, label = 'Female',color='pink')
plt.xticks(X_axis, x)
plt.legend()
plt.savefig('combined_male_female_text2emo.png',format='png',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()
# Out:
# findfont: Font family ['Times Roman'] not found. Falling back to DejaVu Sans.

# %%
#aditya vs rohan poms
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from matplotlib.ticker import PercentFormatter
x=['Anger ','Depression','Fatigue','Viguor','Tension','Confusion']
y1=[49757.15407,235601.24210,27015.10877,22012.82452,39426.65306,35948.01725]
a= [((element/409761) * 100) for element in y1]
y2=[35841.609978418200,152800.369189866000,16426.212635922000,12997.426368800200,23215.296963257200,23827.084713017400]
r= [((element/265108) * 100) for element in y2]
X_axis = np.arange(len(x))
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.size': 10})
plt.bar(X_axis - 0.2, a, 0.4, label = '2020',color='red')
plt.bar(X_axis + 0.2, r, 0.4, label = '2022',color='blue')
plt.xticks(X_axis, x)
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}'))
plt.gca().yaxis.set_major_formatter(PercentFormatter(100))
plt.legend(frameon=False)
plt.savefig('2020_2022_poms.eps',format='eps',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()

# %%
#aditya vs rohan t2e
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from matplotlib.ticker import PercentFormatter
x=['Surprise','Anger','Sadness','Fear','Happiness']
y1=[77044.96000,18040.03000,81670.56000,158511.81000,42133.17000]
a= [((element/409761) * 100) for element in y1]
y2=[42133.17000,12843.410,60230.670,100922.430,27647.420]
r= [((element/265108) * 100) for element in y2]
X_axis = np.arange(len(x))
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.size': 10})
plt.bar(X_axis - 0.2, a, 0.4, label = '2020',color='red')
plt.bar(X_axis + 0.2, r, 0.4, label = '2022',color='blue')
plt.xticks(X_axis, x)
#plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}'))
plt.gca().yaxis.set_major_formatter(PercentFormatter(100,0))
plt.legend(frameon=False)
plt.savefig('2020_2022_t2e.eps',format='eps',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()

# %%
#aditya vs rohan textblob score
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
x=['Positive','Negative','Neutral']


y1=[44474.23112158134,8757.08058168086,17640.842607935243]
a= [((element/409761) * 100) for element in y1]
y2=[27849.269612501932,8442.724857729963,10755.192148473128]
r= [((element/265108) * 100) for element in y2]
X_axis = np.arange(len(x))
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.size': 10})
plt.bar(X_axis - 0.2, a, 0.4, label = '2020',color='red')
plt.bar(X_axis + 0.2, r, 0.4, label = '2022',color='blue')
plt.xticks(X_axis, x)
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}'))
plt.gca().yaxis.set_major_formatter(PercentFormatter(100,0))
plt.legend(frameon=False)
plt.savefig('2020_2022_textblob_score.eps',format='eps',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()

# %%
#aditya vs rohan vader score
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
x=['Positive','Negative','Neutral']
y1=[100592.10009997549,68161.79200000798,4808.136899999978]
a= [((element/409761) * 100) for element in y1]
y2=[54853.08649999646,48023.548100012544,3343.4202999996405]
r= [((element/265108) * 100) for element in y2]
X_axis = np.arange(len(x))
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.size': 10})
plt.bar(X_axis - 0.2, a, 0.4, label = '2020',color='red')
plt.bar(X_axis + 0.2, r, 0.4, label = '2022',color='orange')
plt.xticks(X_axis, x)
#plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))
plt.gca().yaxis.set_major_formatter(PercentFormatter(100,0))
plt.legend(frameon=False)
plt.savefig('2020_2022_vader_score.eps',format='eps',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()

# %%
#aditya vs rohan textblob count
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
x=['Positive','Negative','Neutral']


y1=[110852,21457,277452]
a= [((element/409761) * 100) for element in y1]
y2=[73788,21317,170003]
r= [((element/265108) * 100) for element in y2]
X_axis = np.arange(len(x))
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.size': 10})
plt.bar(X_axis - 0.2, a, 0.4, label = '2020',color='red')
plt.bar(X_axis + 0.2, r, 0.4, label = '2022',color='orange')
plt.xticks(X_axis, x)
#plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}'))
plt.gca().yaxis.set_major_formatter(PercentFormatter(100,0))
plt.legend(frameon=False)
plt.savefig('2020_2022_textblob_count.eps',format='eps',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()

# %%
#aditya vs rohan vader count
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
x=['Positive','Negative','Neutral']

y1=[169621,120056,120084]
a= [((element/409761) * 100) for element in y1]
y2=[96340,87707,81061]
r= [((element/265108) * 100) for element in y2]
X_axis = np.arange(len(x))
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.size': 10})
plt.bar(X_axis - 0.2, a, 0.4, label = '2020',color='red')
plt.bar(X_axis + 0.2, r, 0.4, label = '2022',color='orange')
plt.xticks(X_axis, x)
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}'))
plt.gca().yaxis.set_major_formatter(PercentFormatter(100,0))
plt.legend(frameon=False)
plt.savefig('2020_2022_vader_count.eps',format='eps',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()

# %%
#rnn
#text2emo
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from matplotlib.ticker import PercentFormatter
x=['Surprise','Anger','Sadness','Fear','Joy','Love']
y=[572,2159,4666,1937,5362,1304]
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.size': 10})
barlist=plt.bar(x, y)
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}'))
#plt.gca().yaxis.set_major_formatter(PercentFormatter(1,0))
barlist[0].set_color('yellow')
barlist[1].set_color('r')
barlist[2].set_color('b')
barlist[3].set_color('orange')
barlist[4].set_color('g')
barlist[4].set_color('purple')
plt.savefig('train.eps',format='eps',dpi=1200,facecolor='w',bbox_inches='tight')

plt.show()

# %%
#rnn
#sentistrength
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from matplotlib.ticker import PercentFormatter
x=['Positive','Negative','Neutral']

y1=[86646,218886,104219]
a= [((element/409761) * 100) for element in y1]
y2=[50356,149312,65440]
r= [((element/265108) * 100) for element in y2]
X_axis = np.arange(len(x))
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.size': 10})
plt.bar(X_axis - 0.2, a, 0.4, label = '2020',color='red')
plt.bar(X_axis + 0.2, r, 0.4, label = '2022',color='blue')
plt.xticks(X_axis, x)
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}'))
plt.gca().yaxis.set_major_formatter(PercentFormatter(100,0))
plt.legend(frameon=False)
plt.savefig('2020_2022_senti_strength_count.eps',format='eps',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()
############

# %%
#POMS FOCUS1
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
x=['Anger','Depression','Fatigue','Vigour','Tension','Confusion']
y=[89.16258606,114.3690705,13.16292442,4.332625085,14.9961212,45.97667274]
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.size': 10})
barlist=plt.bar(x, y)
barlist[0].set_color('m')
barlist[1].set_color('black')
barlist[2].set_color('y')
barlist[3].set_color('darkgoldenrod')
barlist[4].set_color('pink')
barlist[5].set_color('cyan')
plt.savefig('poms_focus1.png',format='png',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()

# %%
#POMS FOCUS2
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
x=['Anger','Depression','Fatigue','Vigour','Tension','Confusion']
y=[56.68527072,100.5582509,14.90708434,4.267424382,12.02382609,41.5581434]
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.size': 10})
barlist=plt.bar(x, y)
barlist[0].set_color('m')
barlist[1].set_color('black')
barlist[2].set_color('y')
barlist[3].set_color('pink')
barlist[4].set_color('darkgoldenrod')
barlist[5].set_color('cyan')
plt.savefig('poms_focus2.png',format='png',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()

# %%
#POMS FOCUS3
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
x=['Anger','Depression','Fatigue','Vigour','Tension','Confusion']
y=[122.4444804,199.0780195,27.23501534,7.070292619,24.63772157,75.53447093]
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.family':'Times'})
plt.rcParams.update({'font.size': 10})
barlist=plt.bar(x, y)
barlist[0].set_color('m')
barlist[1].set_color('black')
barlist[2].set_color('y')
barlist[3].set_color('darkgoldenrod')
barlist[4].set_color('pink')
barlist[5].set_color('cyan')
plt.savefig('poms_focus3.png',format='png',dpi=1200,facecolor='w',bbox_inches='tight')
plt.show()
